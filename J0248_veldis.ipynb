# %%
from veldis.veldis import Veldis

# %%
spec = Veldis("../galaxy_spectra/lris-longslit-red-1120/J0248-coadd.fits", informat='pypeit')
# Out:
# Reading spectrum from ../galaxy_spectra/lris-longslit-red-1120/J0248-coadd.fits
# Expected file format: pypeit
#  Spectrum Start:  5649.99
#  Spectrum End:     8926.25
#  Dispersion (1st pixel):   0.77
#  Dispersion (average):      0.80

# %%
spec.plot()

# %%
spec.trimspec(wavrange=[5650, 8875])
# Out:
# spectra has been trimed, now...
#
# wav_min : 5649.986686
#
# wav_max : 8874.745663
#  Spectrum Start:  5649.99
#  Spectrum End:     8874.75
#  Dispersion (1st pixel):   0.77
#  Dispersion (average):      0.80
# <img src="data:image/png;base64,..." width="949.999979409305">

# %%
# %matplotlib notebook
spec.trim_spec.smooth(7)
# Out:
# <img src="data:image/png;base64,..." width="877.2727082583534">

# %%
spec.cal_redshift(CaK=5893.71, CaH=5946.68)
# Out:
#  Observed wavelength for CaK : 5893.710000
#
# redshift z : 0.498273
#
#  Observed wavelength for CaH : 5946.680000
#
# redshift z : 0.498482

# %%
spec.trim_spec.smooth(7)
spec.trim_spec.mark_lines('abs', z=0.498, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-theta       3797.00       5687.91
# H-eta         3835.00       5744.83
# CN bandhd     3883.00       5816.73
# CaII K        3933.67       5892.64
# CaII H        3968.47       5944.77
# H-delta       4101.00       6143.30
# G-band        4305.00       6448.89
# H-gamma       4340.00       6501.32
# Fe4383        4383.00       6565.73
# Ca4455        4455.00       6673.59
# Fe4531        4531.00       6787.44
# H-beta        4861.00       7281.78
# Mg I (b)      5176.00       7753.65
# Na I (D)      5889.95       8823.15
# Na I (D)      5895.92       8832.09

# %%
mask_reg = [(8.6755, 8.6777), (8.8924, 8.8985), (8.9339, 8.9487),
            (8.9862, 8.9902), (9.0289, 9.0331), (9.0531, 9.0544), (9.0635, 9.0658)]
#(8.8361, 8.8440),

# %%
spec.cal_parm(z=0.498, norm=False)
# Out:
# Velocity scale = 41.044799 km/s
# /home/pritom/anaconda3/lib/python3.7/site-packages/veldis-0.1-py3.7.egg/veldis/veldis.py:172: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /home/pritom/anaconda3/lib/python3.7/site-packages/veldis-0.1-py3.7.egg/veldis/veldis.py:177: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
temp_spec = spec.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.68)
# Out:
# vsyst = -146580.691089
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.cal_veldis(temp_spec=temp_spec, mask_reg=mask_reg, degree=[4, 21])
# Out:
# degree : 4
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121386       147     0.052     0.118
# chi2/DOF: 11.99; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 45; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 5
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121387       150     0.055     0.104
# chi2/DOF: 11.99; degree = 5; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 41; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 6
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121385       152     0.054     0.126
# chi2/DOF: 11.94; degree = 6; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 41; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 7
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121393       172     0.048     0.104
# chi2/DOF: 11.89; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 27; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 8
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121369       169    -0.012     0.083
# chi2/DOF: 11.33; degree = 8; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 41; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 9
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121375       167    -0.017     0.093
# chi2/DOF: 11.16; degree = 9; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 45; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 10
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121382       176     0.004     0.113
# chi2/DOF: 10.92; degree = 10; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 44; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  18 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 11
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121379       178     0.020     0.121
# chi2/DOF: 10.86; degree = 11; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 48; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 12
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121389       215     0.028     0.094
# chi2/DOF: 10.72; degree = 12; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 32; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 13
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121385       204     0.050     0.095
# chi2/DOF: 10.71; degree = 13; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 47; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 14
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121388       210     0.030     0.102
# chi2/DOF: 10.69; degree = 14; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 42; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 15
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121393       230     0.041     0.088
# chi2/DOF: 10.65; degree = 15; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 42; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 16
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121398       236     0.055     0.077
# chi2/DOF: 10.54; degree = 16; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 31; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  12 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 17
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121397       235     0.050     0.072
# chi2/DOF: 10.54; degree = 17; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 31; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  12 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 18
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121398       233     0.045     0.083
# chi2/DOF: 10.53; degree = 18; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 35; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  12 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 19
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121395       207     0.028     0.075
# chi2/DOF: 10.49; degree = 19; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 31; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  12 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 20
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    121396       198     0.030     0.083
# chi2/DOF: 10.46; degree = 20; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 31; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1271
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.plot_veldis()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.plot_veldis()
# Out:
# /home/pritom/anaconda3/lib/python3.7/site-packages/veldis-0.1-py3.7.egg/veldis/veldis.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="639.9999861283738">
