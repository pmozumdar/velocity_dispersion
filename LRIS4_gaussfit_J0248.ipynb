# %%
from veldis.gaussian_fit import Gaussfit

# %%
spec = Gaussfit("../galaxy_spectra/lris-longslit-red-1120/J0248-coadd.fits", informat='pypeit')
# Out:
# Reading spectrum from ../galaxy_spectra/lris-longslit-red-1120/J0248-coadd.fits
# Expected file format: pypeit
#  Spectrum Start:  5649.99
#  Spectrum End:     8926.25
#  Dispersion (1st pixel):   0.77
#  Dispersion (average):      0.80
#
#
# sky model is avaiable in the spectra.

# %%
#%matplotlib notebook
spec.plot()

# %%
sky_lines = [(6297, 6305.59), (6360.95, 6370.66), (6530, 6539.56), (6860.28, 6870.59),
             (6920.72, 6929.47), (6946.4, 6955.36), (6975.79, 6984.83), (7338.41, 7347.28),
             (7747.19, 7757.14), (7990.54, 8000.03),  (8397.07, 8405.55),
              (8462.94, 8471.84), (8413.14, 8422.02), (8502.32, 8511.06), (8774.0, 8785.01),
             (8824.69, 8833.09), (8882.78, 8892.1)]

#(6691.9, 6707.43),(7313.48, 7322.83),(7338.41, 7347.28), (7366.77, 7375.66), (7566.86, 7579.69), 
#(8428.02, 8436.93),  (8060.09, 8068.51), (7818.76, 7827.85),

# %%
best_fit = spec.fit_gauss(sky_lines)
# Out:
# Given waverange(assumed) :
#
# 6297 6305.59
# 6360.95 6370.66
# 6530 6539.56
# 6860.28 6870.59
# 6920.72 6929.47
# 6946.4 6955.36
# 6975.79 6984.83
# 7338.41 7347.28
# 7747.19 7757.14
# 7990.54 8000.03
# 8397.07 8405.55
# 8462.94 8471.84
# 8413.14 8422.02
# 8502.32 8511.06
# 8774.0 8785.01
# 8824.69 8833.09
# 8882.78 8892.1
#
# Closest waverange to the given ones :
#
# 6296.813273076806 6305.534115909283
# 6361.091872695685 6370.626332603922
# 6529.952695362879 6539.536083697324
# 6860.304287693537 6870.766976913834
# 6920.693096299906 6929.556117903353
# 6946.471409757919 6955.344693089756
# 6975.499878325239 6985.177744895497
# 7338.380767811183 7347.29488344166
# 7747.5571247711305 7757.280317155107
# 7990.481979518399 8000.189648938516
# 8397.08550190105 8405.927047914833
# 8462.951142566975 8471.778402504928
# 8413.15967144546 8421.997636442855
# 8502.260744773774 8511.080278534479
# 8773.869037785766 8785.005480847014
# 8824.746056162045 8833.482428149679
# ...

# %%
spec.sigma_inst(best_fit=best_fit)
# Out:
# average : 1.648397
