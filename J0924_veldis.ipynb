# %%
from veldis.veldis import Veldis
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from scipy.optimize import curve_fit

# %%
spec = Veldis('../spectra_extraction/spec1d_J0924_coadd_gauss_secondary.fits', informat='fits',
              trimsec=[9558, 13079])
# Out:
# Reading spectrum from ../spectra_extraction/spec1d_J0924_coadd_gauss_secondary.fits
# Expected file format: fits
#  Spectrum Start:  5854.06
#  Spectrum End:     6691.71
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.24

# %%
#%matplotlib notebook
s = spec.plot()
spec.mark_lines('abs', z=0.394)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# G-band        4305.00       6001.17
# H-gamma       4340.00       6049.96
# Fe4383        4383.00       6109.90
# Ca4455        4455.00       6210.27
# Fe4531        4531.00       6316.21

# %%
spec.cal_parm(z=0.394, norm=False)

# %%
temp_spec = spec.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=0.85)
# Out:
# vsyst = -157217.884845
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value

# %%
# %matplotlib notebook
spec.cal_veldis(temp_spec=temp_spec, degree=[2, 14], show_weight=True)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:     99777       243    -0.050     0.020
# chi2/DOF: 0.01470; degree = 2; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 27; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1251
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 3
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:     99782       240    -0.043     0.024
# chi2/DOF: 0.01463; degree = 3; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 27; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1251
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 4
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:     99797       242    -0.017     0.013
# chi2/DOF: 0.01454; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 32; Status: 4
# ...

# %%
spec.plot_veldis(ylim=[210, 280])

# %%
plt.figure(figsize=(7,5))
lam = np.exp(spec.wav_rebinned)/10
plt.plot(lam, spec.flux_rebinned, 'k')
plt.plot(lam, spec.best_fit[0], 'r')
plt.plot(lam, spec.flux_rebinned- spec.best_fit[0], 'd', markersize=3.5, 
         color='LimeGreen')
#plt.axvline(x=lam[0], ymin=0)
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">

# %%
residuals = []

for i, l in enumerate(spec.best_fit):
    residuals.append(spec.flux_rebinned - l)

# %%
r = np.array(residuals).flatten()

# %%
count = plt.hist(r, bins=100)#, histtype='step', color='k')
plt.plot(x, y_norm, 'r', label='gauss_fit')
plt.axvline(x=parm[0]-parm[1], color='k', label='1 sigma')
plt.axvline(x=parm[0]+parm[1], color='k')
plt.text(-0.4, 2000, r'$\mu=0.00073,\ \sigma=0.0577$')
plt.legend()
plt.xlabel('residuals', fontsize=14)
plt.ylabel('frequency', fontsize=14)
plt.title('rest wavelength range(4200-4800)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, 'rest wavelength range(4200-4800)')

# %%
norm_val = len(r)*np.diff(count[1])[0]

def gauss(x, mu, sigma):
    
    return norm.pdf(x, loc=mu, scale=sigma) *norm_val

# %%
x = count[1][:-1] + np.diff(count[1])*0.5

# %%
count[1]
# Out:
# array([-5.55790934e-01, -5.47739315e-01, -5.39687696e-01, -5.31636077e-01,
#        -5.23584458e-01, -5.15532839e-01, -5.07481220e-01, -4.99429601e-01,
#        -4.91377982e-01, -4.83326363e-01, -4.75274744e-01, -4.67223125e-01,
#        -4.59171506e-01, -4.51119887e-01, -4.43068268e-01, -4.35016649e-01,
#        -4.26965030e-01, -4.18913411e-01, -4.10861792e-01, -4.02810173e-01,
#        -3.94758554e-01, -3.86706935e-01, -3.78655316e-01, -3.70603697e-01,
#        -3.62552078e-01, -3.54500460e-01, -3.46448841e-01, -3.38397222e-01,
#        -3.30345603e-01, -3.22293984e-01, -3.14242365e-01, -3.06190746e-01,
#        -2.98139127e-01, -2.90087508e-01, -2.82035889e-01, -2.73984270e-01,
#        -2.65932651e-01, -2.57881032e-01, -2.49829413e-01, -2.41777794e-01,
#        -2.33726175e-01, -2.25674556e-01, -2.17622937e-01, -2.09571318e-01,
#        -2.01519699e-01, -1.93468080e-01, -1.85416461e-01, -1.77364842e-01,
# ...

# %%
parm, covar = curve_fit(gauss, x, count[0])

# %%
parm
# Out:
# array([0.00072601, 0.05772464])

# %%
y_norm = gauss(x, parm[0], parm[1])

# %%
spec1 = Veldis('../spectra_extraction/spec1d_J0924_coadd_gauss_secondary.fits', informat='fits',
              trimsec=[5000, 21000])
# Out:
# Reading spectrum from ../spectra_extraction/spec1d_J0924_coadd_gauss_secondary.fits
# Expected file format: fits
#  Spectrum Start:  4923.23
#  Spectrum End:     9041.35
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.26

# %%
spec1.trimspec(wavrange=[5295, 6720])
spec1.mark_lines('abs', z=0.394)
# Out:
# spectra has been trimmed, now...
#
# wav_min : 5294.976049
#
# wav_max : 6719.988038
#  Spectrum Start:  5294.98
#  Spectrum End:     6719.99
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.23
#
#
#
#
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-eta         3835.00       5345.99
# CN bandhd     3883.00       5412.90
# CaII K        3933.67       5483.54
# CaII H        3968.47       5532.05
# H-delta       4101.00       5716.79
# G-band        4305.00       6001.17
# H-gamma       4340.00       6049.96
# Fe4383        4383.00       6109.90
# Ca4455        4455.00       6210.27
# Fe4531        4531.00       6316.21

# %%
#%matplotlib notebook
spec1.cal_parm(z=0.394, norm=False)

# %%
mask_reg = [(8.6309, 8.6321)]

# %%
temp_spec = spec1.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=0.85)
# Out:
# vsyst = -127125.739616
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value

# %%
spec1.cal_veldis(temp_spec=temp_spec, degree=[2, 14], mask_reg=mask_reg, show_weight=True)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    100489      1000    -0.250     0.228
# chi2/DOF: 0.02242; degree = 2; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 42; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  10 / 1251
#
# degree : 3
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    100602      1000    -0.152     0.253
# chi2/DOF: 0.02223; degree = 3; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 47; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  8 / 1251
#
# degree : 4
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    100736      1000    -0.041     0.261
# chi2/DOF: 0.02200; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  12 / 1251
#
# degree : 5
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:    100724       580    -0.073    -0.041
# ...
