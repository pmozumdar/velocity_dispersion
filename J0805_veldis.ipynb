# %%
from veldis.veldis import Veldis

# %%
spec = Veldis("../galaxy_spectra/lris-longslit-red-1120/spec1d_r201121_0043-J0805+6919_LRISr_2020Nov21T152211.856.fits",
              informat='pypeit')
# Out:
# Reading spectrum from ../galaxy_spectra/lris-longslit-red-1120/spec1d_r201121_0043-J0805+6919_LRISr_2020Nov21T152211.856.fits
# Expected file format: pypeit
#  Spectrum Start:  5652.43
#  Spectrum End:     8928.87
#  Dispersion (1st pixel):   0.77
#  Dispersion (average):      0.80

# %%
# %matplotlib notebook
spec.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.smooth(11)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.cal_redshift(Mgb=6302.52)
# Out:
#  Observed wavelength for Mgb : 6302.520000
#
# redshift z : 0.217643

# %%
spec.smooth(7)
spec.mark_lines('abs', z=0.2176, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="767.2727106425391">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-beta        4861.00       5918.75
# Mg I (b)      5176.00       6302.30
# Na I (D)      5889.95       7171.60
# Na I (D)      5895.92       7178.87
# H-alpha       6562.80       7990.87

# %%
spec.trimspec(wavrange=[5500, 8820])
# Out:
# spectra has been trimmed, now...
#
# wav_min : 5652.428977
#
# wav_max : 8820.226473
#  Spectrum Start:  5652.43
#  Spectrum End:     8820.23
#  Dispersion (1st pixel):   0.77
#  Dispersion (average):      0.80
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
mask_reg = [(8.8348, 8.8450), (8.9338, 8.9521), (9.0142, 9.0172)]

# %%
spec.cal_parm(z=0.2176, norm=False)
# Out:
# Velocity scale = 41.046189 km/s
# <img src="data:image/png;base64,..." width="862.7272540281631">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
temp_spec = spec.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.68)
# Out:
# vsyst = -146710.252891
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.cal_veldis(temp_spec=temp_spec, mask_reg=mask_reg, degree=[4, 21], show_weight=True)
# Out:
# degree : 4
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:     59928       345    -0.099     0.061
# chi2/DOF: 7.791; degree = 4; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 57; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 900
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 5
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:     59935       321    -0.102     0.007
# chi2/DOF: 6.867; degree = 5; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 47; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 900
# <img src="data:image/png;base64,..." width="639.9999861283738">
# degree : 6
#  Best Fit:       Vel     sigma        h3        h4
#  comp.  0:     59935       323    -0.098     0.016
# chi2/DOF: 6.857; degree = 6; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 52; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 900
# ...

# %%
spec.plot_veldis(ylim=[300,355])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### According to 'ppxf' if chi2/DOF is not close to 1 then estimated error from ppxf should not be taken seriously.

# %%
spec.plot_error()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
