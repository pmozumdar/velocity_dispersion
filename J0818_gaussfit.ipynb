# %%
from veldis.gaussian_fit import Gaussfit
import numpy as np
from astropy.io import fits as pf
import matplotlib.pyplot as plt

# %%
spec = Gaussfit('../spectra_extraction/J0818_ESI_spectra/spec1d_J0818_coadd2d_deflector.fits',
                informat='fits', logwav=True, trimsec=[4200,-100])
# Out:
# Reading spectrum from ../spectra_extraction/J0818_ESI_spectra/spec1d_J0818_coadd2d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  6817.45
#  Spectrum End:    10037.49
#  Dispersion (1st pixel):   0.26
#  Dispersion (average):      0.32
#
#
# sky data is not available, so variance is being used as sky model.

# %%
# %matplotlib notebook
spec.plot()
# Out:
# <img src="data:image/png;base64,..." width="813.6363460012708">

# %%
dt = pf.open('../galaxy_spectra/ESI_data/2019_04/J0818-2613_0038_crsub.fits')

# %%
dt[0].data.shape
# Out:
# (2048, 4096)

# %%
sp = np.nanmedian(dt[0].data[1730:, :], axis=0)
# Out:
# /home/pritom/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,

# %%
plt.plot(np.arange(len(sp)), sp)

# %%
spec.sky = sp
spec.wav = np.arange(len(sp))

# %%
spec.plot()

# %%
sky_lines = [(246, 266), (341, 359.5), (448, 465), (897, 914), (950.7, 965.6), (1330, 1350),
             (1389, 1407), (1681, 1711), (1723, 1738), (1971, 1989), (2095, 2112), (2232, 2248), 
             (2612, 2629), (2726, 2752), (2858, 2885)]

# %%
best_fit = spec.fit_gauss(sky_lines)
# Out:
# Given waverange(assumed) :
#
# 246 266
# 341 359.5
# 448 465
# 897 914
# 950.7 965.6
# 1330 1350
# 1389 1407
# 1681 1711
# 1723 1738
# 1971 1989
# 2095 2112
# 2232 2248
# 2612 2629
# 2726 2752
# 2858 2885
#
# Closest waverange to the given ones :
#
# 246 266
# 341 359
# 448 465
# 897 914
# 951 966
# 1330 1350
# 1389 1407
# 1681 1711
# 1723 1738
# 1971 1989
# 2095 2112
# 2232 2248
# 2612 2629
# 2726 2752
# 2858 2885
# Model: Gaussian1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Parameters:
#         amplitude             mean              stddev
#     ------------------ ------------------ ------------------
#     22.303271778089268 2.2488148978234554 2.1425002248764775
# Model: Gaussian1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Parameters:
#         amplitude            mean             stddev
#     ------------------ ---------------- -----------------
#     22.248300418960973 0.99578930721569 2.136399857052081
# Model: Gaussian1D
# Inputs: ('x',)
# ...

# %%
spec.sigma_inst(best_fit=best_fit, ylim=(1.8, 2.8))
# Out:
# average : 2.295523
