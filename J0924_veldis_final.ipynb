# %%
from veldis.veldis import Veldis
import matplotlib.pyplot as plt
import numpy as np
from specim.specfuncs import spec1d

# %%
spec.cal_sis_veldis(0.905, 0.393, 1.523)
# Out:
# velocity dispersion assuming SIS mass profile is 219.153456
# <Quantity 219.15345629>

# %%
spec = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector_new.fits',
              informat='fits', logwav=True, trimsec=[2300, -3150])
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector_new.fits
# Expected file format: fits
#  Spectrum Start:  5350.59
#  Spectrum End:     8305.00
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.26

# %%
#%matplotlib notebook
fg = plt.figure(figsize=(10,6))
spec.smooth(3, fig=fg)
spec.mark_lines('abs', z=0.393, usesmooth=True)
spec.mark_lines('strongem', z=0.393, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# CN bandhd     3883.00       5409.02
# CaII K        3933.67       5479.60
# CaII H        3968.47       5528.08
# H-delta       4101.00       5712.69
# G-band        4305.00       5996.86
# H-gamma       4340.00       6045.62
# Fe4383        4383.00       6105.52
# Ca4455        4455.00       6205.82
# Fe4531        4531.00       6311.68
# H-beta        4861.00       6771.37
# Mg I (b)      5176.00       7210.17
# Na I (D)      5889.95       8204.70
# Na I (D)      5895.92       8213.02
#
#
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-beta        4861.00       6771.37
# [O III]       4962.00       6912.07
# [O III]       5007.00       6974.75

# %%
spec.cal_parm(z=0.393, high_z=True, logscale=True, veldis_start=250, noise_scale=0.07)
# Out:
# The wavelength is red shifted.
# Externally calculated velocity scale = 11.389911 km/s
# velocity scale from ppxf = 11.389943 km/s

# %%
temp_spec = spec.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.3)#, temp_num=300)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -30888.848548
#
# sigma_diff : 1.841057

# %%
mask_reg = np.log(np.array([[5565, 5625], [6740, 7172], [7490, 7730]])/1.393)
                             #[5800, 5960], [5550, 5640],[6480, 6600],[5350, 5430] ,
mask_reg #[6754, 6790], [6850, 7172] #[7747, 7753], [7744, 7798], [6229, 6235], [5800, 5950]  6792], [6850,
# Out:
# array([[8.29279257, 8.30351653],
#        [8.48435551, 8.54648014],
#        [8.58986438, 8.62140445]])

# %%
spec.cal_veldis(temp_spec=temp_spec, degree=[6, 15], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 6
#  Best Fit:       Vel     sigma
#  comp.  0:        20       213
# chi2/DOF: 1.348; degree = 6; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  22 / 1267
#
# degree : 7
#  Best Fit:       Vel     sigma
#  comp.  0:        20       210
# chi2/DOF: 1.347; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  24 / 1267
#
# degree : 8
#  Best Fit:       Vel     sigma
#  comp.  0:        20       206
# chi2/DOF: 1.345; degree = 8; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  21 / 1267
#
# degree : 9
#  Best Fit:       Vel     sigma
#  comp.  0:        18       208
# chi2/DOF: 1.339; degree = 9; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  20 / 1267
#
# ...

# %%
spec.plot_veldis(ylim=[190, 230])

# %%
ord_list = np.array([10])

for od in ord_list:
    fg = plt.figure(figsize=(10,6))
    spec.plot_fit(order=od, boxsize=11, fig=fg)
    print('order : %d' %od)
    plt.show()
# Out:
# order : 10

# %% [markdown]
# ## Red side with larger range

# %%
spec1 = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector_new.fits',
              informat='fits', logwav=True, trimsec=[8371, -3150])
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector_new.fits
# Expected file format: fits
#  Spectrum Start:  6738.65
#  Spectrum End:     8305.00
#  Dispersion (1st pixel):   0.26
#  Dispersion (average):      0.28

# %%
fg = plt.figure(figsize=(10,6))
spec1.smooth(3, fig=fg)
spec1.mark_lines('abs', z=0.393, usesmooth=True)
spec1.mark_lines('strongem', z=0.393, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-beta        4861.00       6771.37
# Mg I (b)      5176.00       7210.17
# Na I (D)      5889.95       8204.70
# Na I (D)      5895.92       8213.02
#
#
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-beta        4861.00       6771.37
# [O III]       4962.00       6912.07
# [O III]       5007.00       6974.75

# %%
spec1.cal_parm(z=0.393, high_z=True, logscale=True, veldis_start=250, noise_scale=0.07)
# Out:
# The wavelength is red shifted.
# Externally calculated velocity scale = 11.389911 km/s
# velocity scale from ppxf = 11.389926 km/s

# %%
temp_spec1 = spec1.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.3)#, temp_num=300)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -100036.999073
#
# sigma_diff : 1.841057

# %%
spec1.cal_veldis(temp_spec=temp_spec1, degree=[2, 12], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:        47       207
# chi2/DOF: 0.8096; degree = 2; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  20 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:        51       204
# chi2/DOF: 0.8094; degree = 3; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  21 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:        57       180
# chi2/DOF: 0.7984; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        58       181
# chi2/DOF: 0.7984; degree = 5; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1267
#
# ...

# %%
spec1.plot_veldis(ylim=[170, 220])

# %% [markdown]
# ## Blue side

# %%
spec_b = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector_new.fits',
              informat='fits', logwav=True, trimsec=[2300, 8370])
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector_new.fits
# Expected file format: fits
#  Spectrum Start:  5350.59
#  Spectrum End:     6738.14
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.23

# %%
fg = plt.figure(figsize=(10,6))
spec_b.smooth(3, fig=fg)
spec_b.mark_lines('abs', z=0.393, usesmooth=True)
spec_b.mark_lines('strongem', z=0.393, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# CN bandhd     3883.00       5409.02
# CaII K        3933.67       5479.60
# CaII H        3968.47       5528.08
# H-delta       4101.00       5712.69
# G-band        4305.00       5996.86
# H-gamma       4340.00       6045.62
# Fe4383        4383.00       6105.52
# Ca4455        4455.00       6205.82
# Fe4531        4531.00       6311.68
#
#
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
#
#
# No lines of the requested type within the wavelength
#  range covered by this spectrum.

# %%
spec_b.cal_parm(z=0.393, high_z=True, logscale=True, veldis_start=250, noise_scale=0.07)
# Out:
# The wavelength is red shifted.
# Externally calculated velocity scale = 11.389911 km/s
# velocity scale from ppxf = 11.389928 km/s

# %%
temp_spec_b = spec_b.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.3)#, temp_num=600)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -30888.848548
#
# sigma_diff : 1.841057

# %%
mask_reg_b = np.log(np.array([ [5545, 5860],  [7477, 7760]])/1.393)
#[6684, 7172] [6750, 7172], [5790, 5990],[5483, 5488],[5790, 5990],

# %%
spec_b.cal_veldis(temp_spec=temp_spec_b, degree=[2, 11], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:         1       190
# chi2/DOF: 2.234; degree = 2; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  18 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:         3       189
# chi2/DOF: 2.233; degree = 3; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:         4       197
# chi2/DOF: 2.216; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:         2       198
# chi2/DOF: 2.214; degree = 5; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1267
#
# ...

# %%
spec_b.plot_veldis(ylim=[160, 230])

# %%
ord_list = np.array([7])

for od in ord_list:
    fg = plt.figure(figsize=(10,6))
    spec_b.plot_fit(order=od, boxsize=11, fig=fg)
    print('order : %d' %od)
    plt.show()
# Out:
# order : 7

# %% [markdown]
# ## Red side

# %%
spec_r = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits',
              informat='fits', logwav=True, trimsec=[10012, -3150])
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  7172.15
#  Spectrum End:     8305.00
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29

# %%
fg = plt.figure(figsize=(10,6))
spec_r.smooth(5, fig=fg)
spec_r.mark_lines('abs', z=0.393, usesmooth=True)
spec_r.mark_lines('strongem', z=0.393, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Mg I (b)      5176.00       7210.17
# Na I (D)      5889.95       8204.70
# Na I (D)      5895.92       8213.02
#
#
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
#
#
# No lines of the requested type within the wavelength
#  range covered by this spectrum.

# %%
spec_r.cal_parm(z=0.393, high_z=True, logscale=True, veldis_start=250, noise_scale=0.07)
# Out:
# The wavelength is red shifted.
# Externally calculated velocity scale = 11.389911 km/s
# velocity scale from ppxf = 11.389922 km/s

# %%
temp_spec_r = spec_r.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.3) #, temp_num=300)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -118727.843252
#
# sigma_diff : 1.841057

# %%
mask_reg_r = np.log(np.array([[5565, 5625], [6740, 7172], [7510, 7730]])/1.393)

# %%
spec_r.cal_veldis(temp_spec=temp_spec_r, degree=[2, 11], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:        50       184
# chi2/DOF: 0.7804; degree = 2; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:        56       177
# chi2/DOF: 0.7796; degree = 3; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:        55       177
# chi2/DOF: 0.7796; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        52       188
# chi2/DOF: 0.7768; degree = 5; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1267
#
# ...

# %%
spec_r.plot_veldis(ylim=[160, 210])

# %%
ord_list = np.array([7])

for od in ord_list:
    fg = plt.figure(figsize=(10,6))
    spec_r.plot_fit(order=od, boxsize=11, fig=fg)
    print('order : %d' %od)
    plt.show()
# Out:
# order : 7

# %% [markdown]
# # Results
#
# ## Systematic uncertainty
#
# ### Systematic uncertainty is calculated by changing wavelength range used to fit for velocity dispersion, degree of additive polynomial and template set. There are three choice for wavelength range- full spectrum, blue side half and red side half.

# %%
veldis_array = []
discard_veldis = []

# %%
## full spectrum

addtive_deg_full = np.arange(6, 16)

for d in addtive_deg_full:
    for i in range(10):
        temp_choice = np.random.choice(temp_spec.shape[1], size=600, replace=False)
        spec.cal_veldis(temp_spec=temp_spec[:, temp_choice], degree=[d, d+1], mask_reg=mask_reg, 
                        show_weight=True, moments=2, plot=False, quiet=True)
        if np.sum(np.array(spec.temp_weight[0]) > 10) > 0:
            discard_veldis.append(spec.vel_dis[0])
        else:
            veldis_array.append(spec.vel_dis[0])
# Out:
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# ...

# %%
print(len(veldis_array), len(discard_veldis))
## blue side
addtive_deg_b = np.arange(2, 11)

for d in addtive_deg_b:
    for i in range(11):
        temp_choice = np.random.choice(temp_spec_b.shape[1], size=600, replace=False)
        spec_b.cal_veldis(temp_spec=temp_spec_b[:, temp_choice], degree=[d, d+1], mask_reg=mask_reg, 
                        show_weight=True, moments=2, plot=False, quiet=True)
        if np.sum(np.array(spec_b.temp_weight[0]) > 10) > 0:
            discard_veldis.append(spec_b.vel_dis[0])
        else:
            veldis_array.append(spec_b.vel_dis[0])

print(len(veldis_array), len(discard_veldis))
# Out:
# 100 0
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# ...

# %%
## red side
addtive_deg_r = np.arange(2, 12)

for d in addtive_deg_r:
    for i in range(10):
        temp_choice = np.random.choice(temp_spec_r.shape[1], size=600, replace=False)
        spec_r.cal_veldis(temp_spec=temp_spec_r[:, temp_choice], degree=[d, d+1], mask_reg=mask_reg, 
                        show_weight=True, moments=2, plot=False, quiet=True)
        if np.sum(np.array(spec_r.temp_weight[0]) > 10) > 0:
            discard_veldis.append(spec_r.vel_dis[0])
        else:
            veldis_array.append(spec_r.vel_dis[0])

print(len(veldis_array), len(discard_veldis))
# Out:
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# ...

# %%
plt.hist(veldis_array, bins=25)
# Out:
# (array([ 1.,  4.,  8., 15., 20., 13., 28., 14., 21., 19., 12., 32., 39.,
#         33., 10.,  6.,  6.,  1.,  5.,  8.,  1.,  1.,  0.,  0.,  2.]),
#  array([170.52098043, 173.4245751 , 176.32816977, 179.23176445,
#         182.13535912, 185.03895379, 187.94254846, 190.84614313,
#         193.74973781, 196.65333248, 199.55692715, 202.46052182,
#         205.3641165 , 208.26771117, 211.17130584, 214.07490051,
#         216.97849518, 219.88208986, 222.78568453, 225.6892792 ,
#         228.59287387, 231.49646854, 234.40006322, 237.30365789,
#         240.20725256, 243.11084723]),
#  <BarContainer object of 25 artists>)

# %%
np.savetxt('J0924_systematic_veldis.txt', np.array(veldis_array), fmt='%f')

# %% [markdown]
# ## Measured systematic uncertainty

# %%
print('systematic uncertainty for population : %d km/s' % int(np.std(veldis_array)))
print('systematic uncertainty for sample : %d km/s' % int(np.std(veldis_array, ddof=1)))
# Out:
# systematic uncertainty for population : 12 km/s
# systematic uncertainty for sample : 12 km/s

# %%
print('mean velocity dispersion : %d km/s' % int(np.mean(veldis_array)))
# Out:
# mean velocity dispersion : 199 km/s

# %% [markdown]
# ## The velocity dispersion value that to be reported is measured using all templates and additive polynomial with degree 10. The degree of the polynomial is decided based on the length of the spectrum which in this case around 3000Ang. But we also masked regions which in total cover around 700 Ang.

# %%
spec.cal_veldis(temp_spec=temp_spec, degree=[10, 11], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 10
#  Best Fit:       Vel     sigma
#  comp.  0:        17       208
# chi2/DOF: 1.339; degree = 10; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  22 / 1267

# %% [markdown]
# ### store best fit data and good pixel values for future use

# %%
gdpix = np.pad(spec.goodpixels[0], (0, len(spec.best_fit[0])- len(spec.goodpixels[0])))
np.savetxt('J0924_bestfit_veldis.txt', np.array([spec.best_fit[0], gdpix]), fmt='%f')

# %%
fit_data = np.loadtxt('J0924_bestfit_veldis.txt')

# %%
plt.figure(figsize=(8,6))
boxsize=15
x = np.exp(spec.wav_rebinned)*1.393
ll, rr = np.min(x), np.max(x)
gal_rebinn = spec1d.Spec1d(wav=x, flux=spec.flux_rebinned, verbose=False)
gal_smooth, varsmooth = gal_rebinn.smooth_boxcar(boxsize, verbose=False)
bst = fit_data[0] #spec.best_fit[0]
goodpixels = np.trim_zeros(fit_data[1], 'b').astype('int')#spec.goodpixels[0]
plt.xlabel(r"Wavelength (Ang)", fontsize=14)
plt.ylabel("Relative Flux", fontsize=14)
plt.plot(x, gal_rebinn['flux'], color='k', label='unsmoothed flux', alpha=0.5)
plt.plot(x, gal_smooth, color='b', linewidth=2, label='smoothed flux')
plt.plot(x, bst, 'r', linewidth=2, label='modelfit')
w = np.flatnonzero(np.diff(goodpixels) > 1)
for wj in w:
    a, b = goodpixels[wj : wj + 2]
    print(x[a], x[b])
    plt.axvspan(x[a], x[b], facecolor='lightgray')
    #plt.plot(x[a : b + 1], resid[a : b + 1], 'b')
    
# If the span is two thin than the function doesn't plot it visbly. So increased the span manually.
#plt.axvspan(5570, 5580, facecolor='lightgray')
plt.legend()
# Out:
# 5564.965804071861 5625.122698839208
# 6739.931768669774 7172.152247310954
# 7489.899666543205 7730.142501449514

# %% [markdown]
# ## Check what is velocity dispersion if the rest wavelength region from 4200-4800 Ang and 5090-5450 Ang are used as Matt suggested.

# %%
spec_new = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits',
              informat='fits', logwav=True)
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  4902.88
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.26

# %%
spec_new.closest_wavelength(np.array([[4200, 4800], [5090, 5450]])*1.393)
# Out:
# Given waverange(assumed) :
#
# 5850.6 6686.4
# 7090.37 7591.85
#
# Closest waverange to the given ones :
#
# 5850.500219829334 6686.371458971489
# 7090.3308375290835 7591.891627349671
# ([(5850.500219829334, 6686.371458971489),
#   (7090.3308375290835, 7591.891627349671)],
#  [(4651, 8166), (9710, 11509)])

# %%
spec1 = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits',
              informat='fits', logwav=True, trimsec=[4650, 8170])
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  5850.28
#  Spectrum End:     6687.13
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.24

# %%
fg = plt.figure(figsize=(10,6))
spec1.smooth(7, fig=fg)
spec1.mark_lines('abs', z=0.393, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# G-band        4305.00       5996.86
# H-gamma       4340.00       6045.62
# Fe4383        4383.00       6105.52
# Ca4455        4455.00       6205.82
# Fe4531        4531.00       6311.68

# %%
spec1.cal_parm(z=0.393, high_z=True, logscale=True, veldis_start=250, noise_scale=0.07)
# Out:
# The wavelength is red shifted.
# Externally calculated velocity scale = 11.389911 km/s
# velocity scale from ppxf = 11.389921 km/s

# %%
temp_spec1 = spec1.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.3) #, temp_num=300)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -57655.139725
#
# sigma_diff : 1.841057

# %%
spec1.cal_veldis(temp_spec=temp_spec1, degree=[2, 7], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:       -38       247
# chi2/DOF: 1.640; degree = 2; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  19 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:       -38       244
# chi2/DOF: 1.639; degree = 3; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:       -55       235
# chi2/DOF: 1.636; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:       -44       237
# chi2/DOF: 1.635; degree = 5; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1267
#
# ...

# %%
spec1.plot_veldis(ylim=[220, 260])

# %%
ord_list = np.array([4])

for od in ord_list:
    fg = plt.figure(figsize=(10,6))
    spec1.plot_fit(order=od, boxsize=11, fig=fg)
    print('order : %d' %od)
    plt.show()
# Out:
# order : 4

# %%
spec2 = Veldis('../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits',
              informat='fits', logwav=True, trimsec=[9710, 11510])
# Out:
# Reading spectrum from ../spectra_extraction/J0924_ESI_spectra/spec1d_J0924_esi_coadd2d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  7090.33
#  Spectrum End:     7591.89
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.28

# %%
fg = plt.figure(figsize=(10,6))
spec2.smooth(7, fig=fg)
spec2.mark_lines('abs', z=0.393, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Mg I (b)      5176.00       7210.17

# %%
spec2.cal_parm(z=0.393, high_z=True, logscale=True, veldis_start=250, noise_scale=0.07)
# Out:
# The wavelength is red shifted.
# Externally calculated velocity scale = 11.389911 km/s
# velocity scale from ppxf = 11.389916 km/s

# %%
temp_spec2 = spec2.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.3) #, temp_num=300
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -115288.090088
#
# sigma_diff : 1.841057

# %%
mask_reg2 = np.log(np.array([[5565, 5625], [6740, 7152], [7560, 7730]])/1.393)

# %%
spec2.cal_veldis(temp_spec=temp_spec2, degree=[2, 7], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:        45       185
# chi2/DOF: 0.7326; degree = 2; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  21 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:        57       177
# chi2/DOF: 0.7312; degree = 3; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  22 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:        59       178
# chi2/DOF: 0.7311; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  24 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        66       177
# chi2/DOF: 0.7306; degree = 5; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  23 / 1267
#
# ...

# %%
spec2.plot_veldis(ylim=[160, 200])

# %%
spec2.cal_veldis(temp_spec=temp_spec2, degree=[2, 7], mask_reg=mask_reg2, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:        40       205
# chi2/DOF: 0.7443; degree = 2; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  22 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:        31       199
# chi2/DOF: 0.7430; degree = 3; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  23 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:        29       184
# chi2/DOF: 0.7394; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  20 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        32       189
# chi2/DOF: 0.7374; degree = 5; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  25 / 1267
#
# ...
