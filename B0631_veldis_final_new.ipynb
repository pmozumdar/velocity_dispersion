# %%
from veldis.veldis import Veldis
import matplotlib.pyplot as plt
import numpy as np
from specim.specfuncs import spec1d

# %%
spec = Veldis('../spectra_extraction/B0631_LRIS_spectra/spec1d_B0631_lris_coadd1d_deflector.fits', 
              informat='fits', trimsec=[635, 3700])
# Out:
# Reading spectrum from ../spectra_extraction/B0631_LRIS_spectra/spec1d_B0631_lris_coadd1d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  6157.39
#  Spectrum End:     8608.76
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80

# %%
fg = plt.figure(figsize=(10,6))
spec.smooth(1, fig=fg)
spec.mark_lines('abs', z=0.620, usesmooth=True)
#spec.mark_lines('strongem', z=0.620, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-eta         3835.00       6212.70
# CN bandhd     3883.00       6290.46
# CaII K        3933.67       6372.55
# CaII H        3968.47       6428.92
# H-delta       4101.00       6643.62
# G-band        4305.00       6974.10
# H-gamma       4340.00       7030.80
# Fe4383        4383.00       7100.46
# Ca4455        4455.00       7217.10
# Fe4531        4531.00       7340.22
# H-beta        4861.00       7874.82
# Mg I (b)      5176.00       8385.12

# %%
spec.cal_parm(z=0.620, high_z=True, logscale=False, veldis_start=250, noise_scale=0.08)
# Out:
# The wavelength is red shifted.
# Velocity scale = 32.790286 km/s

# %%
temp_spec = spec.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.6)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -27734.862676
#
# sigma_diff : 2.010670

# %%
mask_reg = np.log(np.array([(6333, 6356), (6860, 6890), (7135, 7165), (7585, 7700)])/1.62)
print(mask_reg)
# Out:
# [[8.27110319 8.27472838]
#  [8.35103657 8.35540021]
#  [8.39034138 8.39453719]
#  [8.45150174 8.46654946]]

# %%
spec.cal_veldis(temp_spec=temp_spec, degree=[5, 16], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        16       149
# chi2/DOF: 1.111; degree = 5; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  20 / 1267
#
# degree : 6
#  Best Fit:       Vel     sigma
#  comp.  0:        17       147
# chi2/DOF: 1.110; degree = 6; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  21 / 1267
#
# degree : 7
#  Best Fit:       Vel     sigma
#  comp.  0:        17       147
# chi2/DOF: 1.106; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  18 / 1267
#
# degree : 8
#  Best Fit:       Vel     sigma
#  comp.  0:        17       147
# chi2/DOF: 1.106; degree = 8; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1267
#
# degree : 9
#  Best Fit:       Vel     sigma
#  comp.  0:        19       147
# chi2/DOF: 1.085; degree = 9; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  16 / 1267
#
# degree : 10
#  Best Fit:       Vel     sigma
#  comp.  0:        19       147
# chi2/DOF: 1.085; degree = 10; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267
#
# degree : 11
#  Best Fit:       Vel     sigma
#  comp.  0:        19       146
# chi2/DOF: 1.085; degree = 11; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  19 / 1267
#
# degree : 12
#  Best Fit:       Vel     sigma
#  comp.  0:        19       146
# chi2/DOF: 1.084; degree = 12; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1267
#
# degree : 13
#  Best Fit:       Vel     sigma
#  comp.  0:        17       148
# chi2/DOF: 1.073; degree = 13; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1267
#
# degree : 14
#  Best Fit:       Vel     sigma
#  comp.  0:        16       152
# chi2/DOF: 1.072; degree = 14; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1267
#
# degree : 15
#  Best Fit:       Vel     sigma
#  comp.  0:        17       152
# chi2/DOF: 1.072; degree = 15; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1267

# %%
spec.plot_veldis(ylim=[125, 165])

# %%
ord_list = np.array([8])

for od in ord_list:
    fg = plt.figure(figsize=(10,6))
    spec.plot_fit(order=od, boxsize=7, fig=fg)
    print('order : %d' %od)
    plt.show()
# Out:
# order : 8

# %%
spec_b = Veldis('../spectra_extraction/B0631_LRIS_spectra/spec1d_B0631_lris_coadd1d_deflector.fits', 
              informat='fits', trimsec=[635, 2170])
# Out:
# Reading spectrum from ../spectra_extraction/B0631_LRIS_spectra/spec1d_B0631_lris_coadd1d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  6157.39
#  Spectrum End:     7384.88
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80

# %%
fg = plt.figure(figsize=(10,6))
spec_b.smooth(1, fig=fg)
spec_b.mark_lines('abs', z=0.620, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-eta         3835.00       6212.70
# CN bandhd     3883.00       6290.46
# CaII K        3933.67       6372.55
# CaII H        3968.47       6428.92
# H-delta       4101.00       6643.62
# G-band        4305.00       6974.10
# H-gamma       4340.00       7030.80
# Fe4383        4383.00       7100.46
# Ca4455        4455.00       7217.10
# Fe4531        4531.00       7340.22

# %%
spec_b.cal_parm(z=0.620, high_z=True, logscale=False, veldis_start=250, noise_scale=0.08)
# Out:
# The wavelength is red shifted.
# Velocity scale = 35.526070 km/s

# %%
temp_spec_b = spec_b.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.6)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -27734.862676
#
# sigma_diff : 2.010670

# %%
spec_b.cal_veldis(temp_spec=temp_spec_b, degree=[2, 11], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:        27       164
# chi2/DOF: 1.564; degree = 2; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:        26       164
# chi2/DOF: 1.562; degree = 3; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:        29       165
# chi2/DOF: 1.561; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        25       159
# chi2/DOF: 1.557; degree = 5; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1267
#
# degree : 6
#  Best Fit:       Vel     sigma
#  comp.  0:        30       158
# chi2/DOF: 1.545; degree = 6; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  12 / 1267
#
# degree : 7
#  Best Fit:       Vel     sigma
#  comp.  0:        27       164
# chi2/DOF: 1.520; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  9 / 1267
#
# degree : 8
#  Best Fit:       Vel     sigma
#  comp.  0:        26       163
# chi2/DOF: 1.518; degree = 8; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  10 / 1267
#
# degree : 9
#  Best Fit:       Vel     sigma
#  comp.  0:        26       163
# chi2/DOF: 1.518; degree = 9; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  10 / 1267
#
# degree : 10
#  Best Fit:       Vel     sigma
#  comp.  0:        26       168
# chi2/DOF: 1.501; degree = 10; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1267

# %%
spec_b.plot_veldis(ylim=[145, 185])

# %%
ord_list = np.array([8])

for od in ord_list:
    fg = plt.figure(figsize=(10,6))
    spec_b.plot_fit(order=od, boxsize=7, fig=fg)
    print('order : %d' %od)
    plt.show()
# Out:
# order : 8

# %%
spec_r = Veldis('../spectra_extraction/B0631_LRIS_spectra/spec1d_B0631_lris_coadd1d_deflector.fits', 
              informat='fits', trimsec=[2165, 3700]) # logwav=True,
# Out:
# Reading spectrum from ../spectra_extraction/B0631_LRIS_spectra/spec1d_B0631_lris_coadd1d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  7381.68
#  Spectrum End:     8608.76
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80

# %%
fg = plt.figure(figsize=(10,6))
spec_r.smooth(1, fig=fg)
spec_r.mark_lines('abs', z=0.620, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-beta        4861.00       7874.82
# Mg I (b)      5176.00       8385.12

# %%
spec_r.cal_parm(z=0.620, high_z=True, logscale=False, veldis_start=250, noise_scale=0.08)
# Out:
# The wavelength is red shifted.
# Velocity scale = 30.053498 km/s

# %%
temp_spec_r = spec_r.gen_rebinned_temp(lib_path='../TEXT/*', sig_ins=1.6)
# Out:
# 'sig_ins' is red shifted.
#
# As no 'fwhm_temp' value is provided, FWHM for the Indo-US template library will be used as default value
# vsyst = -82101.736496
#
# sigma_diff : 2.010670

# %%
spec_r.cal_veldis(temp_spec=temp_spec_r, degree=[2, 11], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 2
#  Best Fit:       Vel     sigma
#  comp.  0:       -14       140
# chi2/DOF: 0.7625; degree = 2; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  11 / 1267
#
# degree : 3
#  Best Fit:       Vel     sigma
#  comp.  0:       -14       144
# chi2/DOF: 0.7616; degree = 3; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1267
#
# degree : 4
#  Best Fit:       Vel     sigma
#  comp.  0:       -15       147
# chi2/DOF: 0.7607; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  14 / 1267
#
# degree : 5
#  Best Fit:       Vel     sigma
#  comp.  0:        -4       146
# chi2/DOF: 0.7519; degree = 5; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267
#
# degree : 6
#  Best Fit:       Vel     sigma
#  comp.  0:        -6       141
# chi2/DOF: 0.7471; degree = 6; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267
#
# degree : 7
#  Best Fit:       Vel     sigma
#  comp.  0:        -7       140
# chi2/DOF: 0.7471; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1267
#
# degree : 8
#  Best Fit:       Vel     sigma
#  comp.  0:       -11       142
# chi2/DOF: 0.7435; degree = 8; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  13 / 1267
#
# degree : 9
#  Best Fit:       Vel     sigma
#  comp.  0:       -10       139
# chi2/DOF: 0.7416; degree = 9; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  17 / 1267
#
# degree : 10
#  Best Fit:       Vel     sigma
#  comp.  0:       -10       138
# chi2/DOF: 0.7414; degree = 10; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267

# %%
spec_r.plot_veldis(ylim=[120, 160])

# %% [markdown]
# # Results
#
# ## Systematic uncertainty
#
# ### Systematic uncertainty is calculated by changing wavelength range used to fit for velocity dispersion, degree of additive polynomial and template set. There are three choice for wavelength range- full spectrum, blue side half and red side half.

# %%
veldis_array = []
discard_veldis = []

# %%
## full spectrum

addtive_deg_full = np.arange(5, 16)

for d in addtive_deg_full:
    for i in range(10):
        temp_choice = np.random.choice(temp_spec.shape[1], size=600, replace=False)
        spec.cal_veldis(temp_spec=temp_spec[:, temp_choice], degree=[d, d+1], mask_reg=mask_reg, 
                        show_weight=True, moments=2, plot=False, quiet=True)
        if np.sum(np.array(spec.temp_weight[0]) > 10) > 0:
            discard_veldis.append(spec.vel_dis[0])
        else:
            veldis_array.append(spec.vel_dis[0])

print(len(veldis_array), len(discard_veldis))

## blue side
addtive_deg_b = np.arange(2, 11)

for d in addtive_deg_b:
    for i in range(11):
        temp_choice = np.random.choice(temp_spec_b.shape[1], size=600, replace=False)
        spec_b.cal_veldis(temp_spec=temp_spec_b[:, temp_choice], degree=[d, d+1], mask_reg=mask_reg, 
                        show_weight=True, moments=2, plot=False, quiet=True)
        if np.sum(np.array(spec_b.temp_weight[0]) > 10) > 0:
            discard_veldis.append(spec_b.vel_dis[0])
        else:
            veldis_array.append(spec_b.vel_dis[0])

print(len(veldis_array), len(discard_veldis))

## red side
addtive_deg_r = np.arange(2, 11)

for d in addtive_deg_r:
    for i in range(11):
        temp_choice = np.random.choice(temp_spec_r.shape[1], size=600, replace=False)
        spec_r.cal_veldis(temp_spec=temp_spec_r[:, temp_choice], degree=[d, d+1], mask_reg=mask_reg, 
                        show_weight=True, moments=2, plot=False, quiet=True)
        if np.sum(np.array(spec_r.temp_weight[0]) > 10) > 0:
            discard_veldis.append(spec_r.vel_dis[0])
        else:
            veldis_array.append(spec_r.vel_dis[0])

print(len(veldis_array), len(discard_veldis))
# Out:
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 11
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 12
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 13
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 14
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
#
# degree : 15
# 110 0
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
# 209 0
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 2
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 3
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 4
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 5
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 6
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 7
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 8
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 9
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
#
# degree : 10
# 308 0

# %%
plt.hist(veldis_array, bins=25)
# Out:
# (array([ 2.,  1.,  3.,  7.,  6., 16., 20., 23., 32., 20., 23., 29., 22.,
#         13., 10., 13., 12., 11., 13.,  8.,  9.,  6.,  4.,  3.,  2.]),
#  array([131.34595823, 133.10171805, 134.85747788, 136.6132377 ,
#         138.36899752, 140.12475734, 141.88051716, 143.63627698,
#         145.3920368 , 147.14779662, 148.90355644, 150.65931626,
#         152.41507608, 154.1708359 , 155.92659572, 157.68235555,
#         159.43811537, 161.19387519, 162.94963501, 164.70539483,
#         166.46115465, 168.21691447, 169.97267429, 171.72843411,
#         173.48419393, 175.23995375]),
#  <BarContainer object of 25 artists>)

# %%
np.savetxt('B0631_LRIS_systematic_veldis.txt', np.array(veldis_array), fmt='%f')

# %%
print('systematic uncertainty for population : %d km/s' % int(np.std(veldis_array)))
print('systematic uncertainty for sample : %d km/s' % int(np.std(veldis_array, ddof=1)))
# Out:
# systematic uncertainty for population : 8 km/s
# systematic uncertainty for sample : 8 km/s

# %%
print('mean velocity dispersion : %d km/s' % int(np.mean(veldis_array)))
# Out:
# mean velocity dispersion : 151 km/s

# %% [markdown]
# ## The velocity dispersion value that to be reported is measured using all templates and additive polynomial with degree 10. The degree of the polynomial is decided based on the length of the spectrum which in this case around 2450 Ang.

# %%
spec.cal_veldis(temp_spec=temp_spec, degree=[10, 11], mask_reg=mask_reg, show_weight=True, moments=2)
# Out:
# degree : 10
#  Best Fit:       Vel     sigma
#  comp.  0:        19       147
# chi2/DOF: 1.085; degree = 10; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%):  15 / 1267

# %%
gdpix = np.pad(spec.goodpixels[0], (0, len(spec.best_fit[0])- len(spec.goodpixels[0])))
np.savetxt('B0631_LRIS_bestfit_veldis_new.txt', np.array([spec.best_fit[0], gdpix]), fmt='%f')

# %%
fit_data = np.loadtxt('B0631_LRIS_bestfit_veldis_new.txt')

# %%
plt.figure(figsize=(8,6))
boxsize=15
x = np.exp(spec.wav_rebinned)*1.620
ll, rr = np.min(x), np.max(x)
gal_rebinn = spec1d.Spec1d(wav=x, flux=spec.flux_rebinned, verbose=False)
gal_smooth, varsmooth = gal_rebinn.smooth_boxcar(boxsize, verbose=False)
bst = fit_data[0] #spec.best_fit[0]
goodpixels = np.trim_zeros(fit_data[1], 'b').astype('int')#spec.goodpixels[0]
plt.xlabel(r"Wavelength (Ang)", fontsize=14)
plt.ylabel("Relative Flux", fontsize=14)
plt.plot(x, gal_rebinn['flux'], color='k', label='unsmoothed flux', alpha=0.5)
plt.plot(x, gal_smooth, color='b', linewidth=2, label='smoothed flux')
plt.plot(x, bst, 'r', linewidth=2, label='modelfit')
w = np.flatnonzero(np.diff(goodpixels) > 1)
for wj in w:
    a, b = goodpixels[wj : wj + 2]
    print(x[a], x[b])
    plt.axvspan(x[a], x[b], facecolor='lightgray')
    #plt.plot(x[a : b + 1], resid[a : b + 1], 'b')
    
# If the span is two thin than the function doesn't plot it visbly. So increased the span manually.
#plt.axvspan(5570, 5580, facecolor='lightgray')
plt.legend()
# Out:
# 6332.859276085376 6356.453790359381
# 6859.991121750792 6890.069778154632
# 7134.715348051042 7165.214824029415
# 7584.554577128609 7700.746232034833

# %% [markdown]
# ## SIS velocity dispersion
#
# ### As source redshift is unknown for this system we can measure some scaled SIS velocity dispersion. The einstein radius and source redshift information used from Cameron's database.¶

# %%
sis_vel = []
source_z = np.arange(2.0, 4.1, 0.1)
for z in source_z:
    sis_vel.append(spec.cal_sis_veldis(0.58, 0.62, z, verbose=False ))
plt.plot(source_z, sis_vel)
